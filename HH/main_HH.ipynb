# %%
import pandas as pd

# %%
df = pd.read_csv("data scientist.csv")

# %%
df.head()
# Out:
#    Unnamed: 0        id  premium  \
# 0           0  30501311    False
# 1           1  30560697    False
# 2           2  30501182    False
# 3           3  29632581    False
# 4           4  30491785    False
#
#                                                 name department  has_test  \
# 0                              Python Data Scientist        NaN     False
# 1                                     Data Scientist        NaN     False
# 2                                Data Scientist (ML)        NaN     False
# 3  Ведущий специалист / data scientist (big data,...        NaN     False
# 4                                     Data scientist        NaN     False
#
#    response_letter_required  \
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False
#
#                                                 area  \
# 0  {'id': '1', 'name': 'Москва', 'url': 'https://...
# 1  {'id': '1', 'name': 'Москва', 'url': 'https://...
# 2  {'id': '1', 'name': 'Москва', 'url': 'https://...
# 3  {'id': '1', 'name': 'Москва', 'url': 'https://...
# 4  {'id': '1', 'name': 'Москва', 'url': 'https://...
#
#                                               salary  \
# 0  {'from': 110000, 'to': None, 'currency': 'RUR'...
# 1  {'from': 180000, 'to': None, 'currency': 'RUR'...
# 2                                                NaN
# 3  {'from': 150000, 'to': None, 'currency': 'RUR'...
# 4                                                NaN
#
#                                  type  ...              published_at  \
# 0  {'id': 'open', 'name': 'Открытая'}  ...  2019-03-23T14:27:23+0300
# 1  {'id': 'open', 'name': 'Открытая'}  ...  2019-03-23T10:52:32+0300
# 2  {'id': 'open', 'name': 'Открытая'}  ...  2019-03-23T14:24:18+0300
# 3  {'id': 'open', 'name': 'Открытая'}  ...  2019-03-23T11:23:33+0300
# 4  {'id': 'open', 'name': 'Открытая'}  ...  2019-03-23T11:05:23+0300
#
#                  created_at  archived  \
# 0  2019-03-23T14:27:23+0300     False
# 1  2019-03-23T10:52:32+0300     False
# 2  2019-03-23T14:24:18+0300     False
# 3  2019-03-23T11:23:33+0300     False
# 4  2019-03-23T11:05:23+0300     False
#
#                                  apply_alternate_url insider_interview  \
# 0  https://hh.ru/applicant/vacancy_response?vacan...               NaN
# 1  https://hh.ru/applicant/vacancy_response?vacan...               NaN
# 2  https://hh.ru/applicant/vacancy_response?vacan...               NaN
# 3  https://hh.ru/applicant/vacancy_response?vacan...               NaN
# 4  https://hh.ru/applicant/vacancy_response?vacan...               NaN
#
#                                                url  \
# 0  https://api.hh.ru/vacancies/30501311?host=hh.ru
# 1  https://api.hh.ru/vacancies/30560697?host=hh.ru
# 2  https://api.hh.ru/vacancies/30501182?host=hh.ru
# 3  https://api.hh.ru/vacancies/29632581?host=hh.ru
# 4  https://api.hh.ru/vacancies/30491785?host=hh.ru
#
#                     alternate_url relations  \
# 0  https://hh.ru/vacancy/30501311        []
# 1  https://hh.ru/vacancy/30560697        []
# 2  https://hh.ru/vacancy/30501182        []
# 3  https://hh.ru/vacancy/29632581        []
# 4  https://hh.ru/vacancy/30491785        []
#
#                                              snippet  \
# 0  {'requirement': 'Высшее техническое/математиче...
# 1  {'requirement': 'Высшее образование в области ...
# 2  {'requirement': 'Python. Хорошее знание библио...
# 3  {'requirement': 'Математическое, естественнона...
# 4  {'requirement': 'Высшее техническое/математиче...
#
#                                             contacts
# 0                                                NaN
# 1  {'name': 'Бухарова Юлия', 'email': 'j.bukharov...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 24 columns]

# %%
df.rename(columns={'Unnamed: 0':'index'}, inplace=True)
df.set_index('index', inplace=True)

# %%
df.head()
# Out:
#              id  premium                                               name  \
# index
# 0      30501311    False                              Python Data Scientist
# 1      30560697    False                                     Data Scientist
# 2      30501182    False                                Data Scientist (ML)
# 3      29632581    False  Ведущий специалист / data scientist (big data,...
# 4      30491785    False                                     Data scientist
#
#       department  has_test  response_letter_required  \
# index
# 0            NaN     False                     False
# 1            NaN     False                     False
# 2            NaN     False                     False
# 3            NaN     False                     False
# 4            NaN     False                     False
#
#                                                     area  \
# index
# 0      {'id': '1', 'name': 'Москва', 'url': 'https://...
# 1      {'id': '1', 'name': 'Москва', 'url': 'https://...
# 2      {'id': '1', 'name': 'Москва', 'url': 'https://...
# 3      {'id': '1', 'name': 'Москва', 'url': 'https://...
# 4      {'id': '1', 'name': 'Москва', 'url': 'https://...
#
#                                                   salary  \
# index
# 0      {'from': 110000, 'to': None, 'currency': 'RUR'...
# 1      {'from': 180000, 'to': None, 'currency': 'RUR'...
# 2                                                    NaN
# 3      {'from': 150000, 'to': None, 'currency': 'RUR'...
# 4                                                    NaN
#
#                                      type  \
# index
# 0      {'id': 'open', 'name': 'Открытая'}
# 1      {'id': 'open', 'name': 'Открытая'}
# 2      {'id': 'open', 'name': 'Открытая'}
# 3      {'id': 'open', 'name': 'Открытая'}
# 4      {'id': 'open', 'name': 'Открытая'}
#
#                                                  address  ...  \
# index                                                     ...
# 0                                                    NaN  ...
# 1      {'city': None, 'street': None, 'building': Non...  ...
# 2                                                    NaN  ...
# 3      {'city': 'Москва', 'street': 'Кузнецкий мост',...  ...
# 4      {'city': 'Москва', 'street': 'Пресненская набе...  ...
#
#                    published_at                created_at archived  \
# index
# 0      2019-03-23T14:27:23+0300  2019-03-23T14:27:23+0300    False
# 1      2019-03-23T10:52:32+0300  2019-03-23T10:52:32+0300    False
# 2      2019-03-23T14:24:18+0300  2019-03-23T14:24:18+0300    False
# 3      2019-03-23T11:23:33+0300  2019-03-23T11:23:33+0300    False
# 4      2019-03-23T11:05:23+0300  2019-03-23T11:05:23+0300    False
#
#                                      apply_alternate_url insider_interview  \
# index
# 0      https://hh.ru/applicant/vacancy_response?vacan...               NaN
# 1      https://hh.ru/applicant/vacancy_response?vacan...               NaN
# 2      https://hh.ru/applicant/vacancy_response?vacan...               NaN
# 3      https://hh.ru/applicant/vacancy_response?vacan...               NaN
# 4      https://hh.ru/applicant/vacancy_response?vacan...               NaN
#
#                                                    url  \
# index
# 0      https://api.hh.ru/vacancies/30501311?host=hh.ru
# 1      https://api.hh.ru/vacancies/30560697?host=hh.ru
# 2      https://api.hh.ru/vacancies/30501182?host=hh.ru
# 3      https://api.hh.ru/vacancies/29632581?host=hh.ru
# 4      https://api.hh.ru/vacancies/30491785?host=hh.ru
#
#                         alternate_url relations  \
# index
# 0      https://hh.ru/vacancy/30501311        []
# 1      https://hh.ru/vacancy/30560697        []
# 2      https://hh.ru/vacancy/30501182        []
# 3      https://hh.ru/vacancy/29632581        []
# 4      https://hh.ru/vacancy/30491785        []
#
#                                                  snippet  \
# index
# 0      {'requirement': 'Высшее техническое/математиче...
# 1      {'requirement': 'Высшее образование в области ...
# 2      {'requirement': 'Python. Хорошее знание библио...
# 3      {'requirement': 'Математическое, естественнона...
# 4      {'requirement': 'Высшее техническое/математиче...
#
#                                                 contacts
# index
# 0                                                    NaN
# 1      {'name': 'Бухарова Юлия', 'email': 'j.bukharov...
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
#
# [5 rows x 23 columns]

# %%
import ast
df.salary = df.salary.dropna()


salaries = df.salary.dropna()
currencies = [ast.literal_eval(salaries.iloc[i])['currency'] for i in range(len(salaries))]
curr = set(currencies) #{'EUR', 'RUR', 'USD'}


rur = [ast.literal_eval(salaries.iloc[i]) for i in range(len(salaries)) if ast.literal_eval(salaries.iloc[i])['currency']=='RUR']
eur = [ast.literal_eval(salaries.iloc[i]) for i in range(len(salaries)) if ast.literal_eval(salaries.iloc[i])['currency']=='EUR']
usd = [ast.literal_eval(salaries.iloc[i]) for i in range(len(salaries)) if ast.literal_eval(salaries.iloc[i])['currency']=='USD']


fr = [x['from'] for x in rur]
fr = list(filter(lambda x: x is not None, fr))

to = [x['to'] for x in rur]
to = list(filter(lambda x: x is not None, to))

import numpy as np
salary_range = list(zip(fr, to))
av = map(np.mean, salary_range)
av = round(np.mean(list(av)),1)


print("average salary as Data Scientist ", av, "rubles")
# Out:
# average salary as Data Scientist  152333.3 rubles

# %%
from collections import Counter

# %%
vacancy_names = df.name

# %%
vacancy_names
# Out:
# index
# 0                                  Python Data Scientist
# 1                                         Data Scientist
# 2                                    Data Scientist (ML)
# 3      Ведущий специалист / data scientist (big data,...
# 4                                         Data scientist
# 5             Data scientist (Machine Learning Engineer)
# 6                                  Cтажер Data Scientist
# 7                       Data Scientist (Computer Vision)
# 8                       Data Scientist (Computer Vision)
# 9          Lead Data Scientist \ Ведущий аналитик данных
# 10                                        Data-Scientist
# 11                                        Data Scientist
# 12                                        Data scientist
# 13                  Data Analyst/Data Scientist Q-Portal
# 14                                        Data Scientist
# 15                                        Data Scientist
# 16                                        Data Scientist
# 17        Data Scientist/Finance Quantitative Researcher
# 18                                        Data Scientist
# 19                                        Data Scientist
# 20                      Data Scientist / Аналитик данных
# 21                                        Data Scientist
# 22                                 Data scientist/Python
# 23                                        Data Scientist
# 24              Аналитик - эконометрист / Data scientist
# 25                      Data Scientist (event detection)
# 26                                        Data Scientist
# 27                           Data Analyst/Data Scientist
# 28                  Junior Quant Trader / Data Scientist
# 29                 Исследователь данных / Data Scientist
#                              ...
# 330                           Начальник отдела аналитики
# 331                                        Data Engineer
# 332                 Руководитель отдела CRM / лояльности
# 333                                        Data Engineer
# 334       Product Analyst / Data Analyst в Контакт центр
# 335                                Ведущий Data Engineer
# 336                     Scientist (Philips Skolkovo Lab)
# 337                                      Бизнес-аналитик
# 338          Инженер по обработке данных (Data Engineer)
# 339    Руководитель группы развития процессов и техно...
# 340                     Руководитель по бизнес-аналитике
# 341                   Разработчик Java для AI/NLP систем
# 342                 Senior Software Developer (Datalore)
# 343                 Senior Software Developer (Datalore)
# 344                         Scientist (Philips Research)
# 345                                 Java/Scala Developer
# 346                      Системный администратор (Linux)
# 347                               Backend Engineer (R&D)
# 348                           Retail Business Consultant
# 349                                      ETL-разработчик
# 350                                        Data Engineer
# 351              Архитектор/team lead в отдел разработки
# 352                     Менеджер продукта/ Product Owner
# 353                        Разработчик-исследователь NLP
# 354                                       AI/ML Engineer
# 355          Business consultant (Customer Intelligence)
# 356         Medical Adviser (Hospital product portfolio)
# 357             Старший разработчик C# ASP.NET (backend)
# 358                                             Аналитик
# 359                   Разработчик ETL-системы в Я.Музыку
# Name: name, Length: 360, dtype: object

# %%
cloud = Counter(vacancy_names)

# %%
from wordcloud import WordCloud, STOPWORDS

# %%
stopwords = set(STOPWORDS)

# %%
cloud = ''
for x in list(vacancy_names):
    cloud+=x+' '

# %%
wordcloud = WordCloud(width = 800, height = 800, 
     
                stopwords = stopwords, 
                min_font_size = 8,background_color='white'
                     ).generate(cloud)

# %%
wordcloud

# %%
import matplotlib.pylab as plt
plt.figure(figsize = (16, 16)) 
plt.imshow(wordcloud)
plt.savefig('vacancy_cloud.png')
